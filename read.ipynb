# %%
import pandas as pd 

sales = pd.read_csv("sales.csv") 

print(sales)
# Out:
#    order_id  order_date customer_name         product     category  quantity  \
# 0    ORD001  2026-08-01          John     Dell Laptop  Electronics         1
# 1    ORD002  2026-08-01         Maria  Wireless Mouse  Accessories         2
# 2    ORD003  2026-08-02         Pedro        Keyboard  Accessories         1
# 3    ORD004  2026-08-02           Ana    Office Chair    Furniture         2
# 4    ORD005  2026-08-03          John         Monitor  Electronics         1
# 5    ORD006  2026-08-03        Carlos       USB Cable  Accessories         5
# 6    ORD007  2026-08-04         Maria            Desk    Furniture         1
# 7    ORD008  2026-08-04         Pedro       HP Laptop  Electronics         1
# 8    ORD009  2026-08-05           Ana  Wireless Mouse  Accessories         3
# 9    ORD010  2026-08-05        Carlos    Office Chair    Furniture         1
# 10   ORD011  2026-08-06          John        Keyboard  Accessories         2
# ...

# %%
products = pd.read_csv("products.csv")

print(products)
# Out:
#   product_id    product_name     category  unit_price  stock_quantity
# 0       P001     Dell Laptop  Electronics       45000              15
# 1       P002       HP Laptop  Electronics       42000              12
# 2       P003         Monitor  Electronics        8500              25
# 3       P004  Wireless Mouse  Accessories         750              50
# 4       P005        Keyboard  Accessories        1200              40
# 5       P006       USB Cable  Accessories         250             100
# 6       P007    Office Chair    Furniture        3500              20
# 7       P008            Desk    Furniture        5500              15
